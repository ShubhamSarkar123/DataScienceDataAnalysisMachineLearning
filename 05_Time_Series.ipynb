# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamSarkar123/DataScienceDataAnalysisMachineLearning/blob/main/05_Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9cfc677-f5c7-4f95-8bfd-3d1cfb55bc11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9cfc677-f5c7-4f95-8bfd-3d1cfb55bc11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fremont-bridge.csv to fremont-bridge.csv

# %%
data = pd.read_csv("fremont-bridge.csv", index_col= 'Date')
data.head()
# Out:
#                 West  East
# Date
# 10/3/2012 0:00   4.0   9.0
# 10/3/2012 1:00   4.0   6.0
# 10/3/2012 2:00   1.0   1.0
# 10/3/2012 3:00   2.0   3.0
# 10/3/2012 4:00   6.0   1.0

# %%
data.columns = ["West", "East"]
data["Total"] = data["West"] + data["East"] 
data.head()
# Out:
#                 West  East  Total
# Date
# 10/3/2012 0:00   4.0   9.0   13.0
# 10/3/2012 1:00   4.0   6.0   10.0
# 10/3/2012 2:00   1.0   1.0    2.0
# 10/3/2012 3:00   2.0   3.0    5.0
# 10/3/2012 4:00   6.0   1.0    7.0

# %%
data.dropna().describe()
# Out:
#                West          East         Total
# count  45976.000000  45976.000000  45976.000000
# mean      54.712306     55.479315    110.191622
# std       72.935797     80.232055    139.189603
# min        0.000000      0.000000      0.000000
# 25%        7.000000      7.000000     15.000000
# 50%       29.000000     28.000000     60.000000
# 75%       72.000000     68.000000    144.000000
# max      854.000000    717.000000   1165.000000

# %%
import matplotlib.pyplot as plt
import seaborn
seaborn.set()
data.plot()
plt.ylabel("Hourly Bicycle count")
plt.show()
